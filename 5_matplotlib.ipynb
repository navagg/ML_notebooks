# %% [markdown]
# ## Matplotlib
# (c) Naveen Aggarwal

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5]) 
plt.ylabel('some significant numbers') 
plt.xlabel('Range')
plt.show()

# %%
import numpy as np 
# evenly sampled time at .2 intervals 
t = np.arange(0., 5., 0.2) 
# red dashes, blue squares and green triangles 
 
plt.plot(t,t, 'r--')
plt.axis([0, 6, 0, 150]) # x and y range of axis 
plt.show() 
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
plt.plot([1,2,3], [1,4,9], 'go-', label='line 1', linewidth=3)
plt.show()

# %% [markdown]
# ### For more information visit the following doc
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
def f(t): 
    return np.exp(-t) * np.cos(2*np.pi*t) 
t1 = np.arange(0.0, 5.0, 0.1) 
t2 = np.arange(0.0, 5.0, 0.02) 
plt.figure(1) # Called implicitly
# for multiple figures 
plt.subplot(211) # 2 rows, 1 column, 1st plot 
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k') 
plt.subplot(212) # 2 rows, 1 column, 2nd plot 
plt.plot(t2, np.cos(2*np.pi*t2), 'r--') 
plt.show() 
#%%

# %% [markdown]
# ##### Create a line graph of CO2 versus time. View the plot.

# %%
times = range(7)
co2 = [250, 265, 272, 260, 300, 320, 389]
plt.plot(times, co2)
plt.plot(times, co2, 'b--')
plt.title("Concentration of CO2 versus time")
plt.ylabel("[CO2]")
plt.xlabel("Time (decade)")
plt.show()

# %% [markdown]
# ##### Continuing with the above data plot, add some additional data

# %%
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2]
plt.plot(times, co2, 'b--', times, temp, 'r*-')
plt.show()
plt.savefig("co2_temp.pdf")

# %% [markdown]
# ##### Multiple axes

# %%
fig, ax1 = plt.subplots()
times = range(7)
co2 = [250, 265, 272, 260, 300, 320, 389]
ax1.plot(times, co2, "b--")
ax1.set_ylabel("[CO2]")
ax2 = ax1.twinx()
temp = [14.1, 15.5, 16.3, 18.1, 17.3, 19.1, 20.2]
ax2.plot(times, temp, "r*-")
ax2.set_ylabel("Temp (degC)")
plt.show()

# %% [markdown]
# ##### Multiple Plots

# %%
plt.subplot(1, 3, 1)
x = range(0, 10, 1)
plt.plot(x)
plt.subplot(1, 3, 2)
y = range(10, 0, -1)
plt.plot(y)
plt.subplot(1, 3, 3)
z = [4] * 10
plt.plot(z)
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
mu, sigma = 100, 25 
x = mu + sigma * np.random.randn(10000) 
# the histogram of the data 
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='b', alpha=0.7) 
plt.xlabel('Smarts') 
plt.ylabel('Probability') 
plt.title('Histogram of IQ') 
plt.text(60, .025, '$\mu=100,\ \sigma=15$', color='r') #TeX equations 
plt.axis([40, 160, 0, 0.03]) 
plt.grid(True) 
plt.show() 
print(n, bins,patches)
# Out:
# [2.47693152e-05 0.00000000e+00 4.95386303e-05 0.00000000e+00
#  1.23846576e-04 1.23846576e-04 1.98154521e-04 2.47693152e-04
#  4.21078358e-04 5.69694249e-04 8.17387400e-04 1.04031124e-03
#  1.85769864e-03 2.20446905e-03 3.02185645e-03 4.13647563e-03
#  4.97863235e-03 6.53909920e-03 7.97571948e-03 1.02792658e-02
#  1.18645020e-02 1.32020450e-02 1.34497381e-02 1.59514390e-02
#  1.52083595e-02 1.59762083e-02 1.58028231e-02 1.53074368e-02
#  1.43662028e-02 1.31525063e-02 1.21369644e-02 9.68480223e-03
#  8.29772058e-03 7.62894907e-03 5.96940495e-03 4.73093920e-03
#  3.12093371e-03 2.47693152e-03 1.63477480e-03 1.13938850e-03
#  6.93540824e-04 5.44924934e-04 2.97231782e-04 1.98154521e-04
#  1.23846576e-04 7.43079455e-05 0.00000000e+00 2.47693152e-05
#  0.00000000e+00 2.47693152e-05] [ -3.21080069   0.82645264   4.86370596   8.90095929  12.93821261
#   16.97546594  21.01271927  25.04997259  29.08722592  33.12447924
#   37.16173257  41.19898589  45.23623922  49.27349254  53.31074587
#   57.3479992   61.38525252  65.42250585  69.45975917  73.4970125
#   77.53426582  81.57151915  85.60877247  89.6460258   93.68327913
#   97.72053245 101.75778578 105.7950391  109.83229243 113.86954575
#  117.90679908 121.94405241 125.98130573 130.01855906 134.05581238
#  138.09306571 142.13031903 146.16757236 150.20482568 154.24207901
#  158.27933234 162.31658566 166.35383899 170.39109231 174.42834564
#  178.46559896 182.50285229 186.54010561 190.57735894 194.61461227
#  198.65186559] <a list of 50 Patch objects>

# %%
import scipy
import matplotlib.pyplot as plt
import scipy.io.wavfile
sample_rate, X = scipy.io.wavfile.read('congestion.wav')
#print (sample_rate, X.shape )
plt.specgram(X, Fs=sample_rate, xextent=(0,30))
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import librosa as lb
import librosa.display
y, sr = lb.load('congestion.wav')
plt.figure(figsize=(12, 8))
D= lb.amplitude_to_db(lb.stft(y), ref=np.max)
plt.subplot(4, 2, 1)
lb.display.specshow(D, y_axis='linear')
plt.colorbar()
plt.title('Linear-frequency power spectrogram')
plt.show()
# Out:
# D:\ProgramData\Anaconda\lib\site-packages\librosa\display.py:656: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   if np.issubdtype(data.dtype, np.complex):
